# %%
# Create a project to start transaction on a ATM kiosk, store pin and amount.

import numpy as np

account = np.array([1234, 5000])

def atm():
    pin = int(input("Enter your PIN: "))

    if pin == account[0]:
        print("Login Successful")

        while True:
            print("\n1. Check Balance")
            print("2. Withdraw")
            print("3. Deposit")
            print("4. Exit")

            choice = int(input("Enter your choice: "))

            if choice == 1:
                print("Your Balance is:", account[1])

            elif choice == 2:
                amount = int(input("Enter withdraw amount: "))
                if amount <= account[1]:
                    account[1] = account[1] - amount
                    print("Withdrawal Successful")
                    print("Remaining Balance:", account[1])
                else:
                    print("Insufficient Balance")

            elif choice == 3:
                amount = int(input("Enter deposit amount: "))
                account[1] = account[1] + amount
                print("Deposit Successful")
                print("Updated Balance:", account[1])

            elif choice == 4:
                print("Thank you for using ATM")
                break

            else:
                print("Invalid Choice")

    else:
        print("Incorrect PIN")

atm()
# Out:
# Enter your PIN: 1234
# Login Successful
#
# 1. Check Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Enter your choice: 2
# Enter withdraw amount: 4000
# Withdrawal Successful
# Remaining Balance: 1000
#
# 1. Check Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Enter your choice: 3
# Enter deposit amount: 8000
# Deposit Successful
# Updated Balance: 9000
#
# 1. Check Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Enter your choice: 1
# Your Balance is: 9000
#
# 1. Check Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Enter your choice: 4
# Thank you for using ATM
